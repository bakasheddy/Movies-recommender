# %%
import requests
import pandas as pd
import time
import numpy as np

# %%
# TMDb API key
api_key = 'df52b87fbcb7dda06ba6e2dd775082cd'

# Base URL for TMDb API
base_url = 'https://api.themoviedb.org/3'

# Endpoint to get popular people
endpoint = '/person/popular'

# List to store data from all pages
all_people = []

# Loop through pages 1 to 1000
for page in range(1, 1001):
    # Full URL for the API request
    url = f'{base_url}{endpoint}?language=en-US&page={page}'
    
    # Headers including the authorization bearer token
    headers = {
        "accept": "application/json",
        "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJkZjUyYjg3ZmJjYjdkZGEwNmJhNmUyZGQ3NzUwODJjZCIsInN1YiI6IjY2NjMwMmJkYjJjNjEwNTIxNTE0ZmEwOSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.ODtRxFBVDhxaAd_LwBPLyC_LI_CLnHhG5yxSuNqLIIs"
    }
    
    # Send the GET request to the API
    response = requests.get(url, headers=headers)
    
    # Check if the request was successful
    if response.status_code == 200:
        # Parse the JSON response
        popular_people_dict = response.json()
        
        # Add the results to the list
        all_people.extend(popular_people_dict['results'])
    else:
        # Print the error code if the request was not successful
        print(f'Error: {response.status_code}, {response.text}')
        break
    
    # Wait for 1.5 seconds before the next request to avoid hitting the rate limit
    time.sleep(1.5)

# Convert the list of all people to a DataFrame
df = pd.DataFrame(all_people)

# %%
df.head()
# Out:
#    adult  gender       id known_for_department             name  \
# 0  False       2    12799               Acting     Jeremy Piven
# 1  False       2  2786960               Acting  Gabriel Guevara
# 2  False       2      976               Acting    Jason Statham
# 3  False       1   115440               Acting   Sydney Sweeney
# 4  False       1  3775928               Acting   Julia Victoria
#
#      original_name  popularity                      profile_path  \
# 0     Jeremy Piven     201.728  /pqdR8zqAWF87chGYlbdYr0YfC7g.jpg
# 1  Gabriel Guevara     149.828  /pviRYKEEmoPUfLYwP1VHJ6LQcRg.jpg
# 2    Jason Statham     121.863  /whNwkEQYWLFJA8ij0WyOOAD5xhQ.jpg
# 3   Sydney Sweeney     131.117  /qYiaSl0Eb7G3VaxOg8PxExCFwon.jpg
# 4   Julia Victoria     126.313  /3Xm4zDO3gUVU4OWZnhb983GnEGx.jpg
#
#                                            known_for
# 0  [{'backdrop_path': '/sd4xN5xi8tKRPrJOWwNiZEile...
# 1  [{'backdrop_path': '/lntyt4OVDbcxA1l7LtwITbrD3...
# ...

# %%
df.shape
# Out:
# (10000, 9)

# %%
df.to_csv('people.csv',index=False)

# %%
df.sample(20)
# Out:
#                         backdrop_path_x       id  \
# 16237  /y8yvIrmoM2PLuJcSto7OmOfsXQj.jpg      440
# 18977  /1oRug23GWxgyQmqQGbX7ke974lp.jpg     5902
# 7049   /wUXZ8KjLreDJPW3RCZTxrgJkb3i.jpg   336560
# 10255  /sXM9H9cpeErz7xvuhC61NMR6pks.jpg    13008
# 11044  /cCo3gKTHBVS5FKjvGQu0VSfVHW3.jpg   594003
# 20321  /q0Y73Hf0604PqnnqKybaumMLBy6.jpg    10379
# 19779  /cd3oGh0ZuaB794UIz9G4c79OEDY.jpg    54433
# 13169  /n6ggvrNiiDBGcymaomQPeVsIfUg.jpg    16995
# 24306  /oHsiqHajO9v8YTuonvcMCkxtpSq.jpg     9714
# 3783   /b6gTSFOHnP1gzu3TXNgHAh3gLNs.jpg   756982
# 21383  /c4jwzF8rAD3c2YpPlRwrDAxWzT3.jpg   471968
# 19063  /sHHtfylgVd5A1pjBxKEPksF6eTC.jpg    12690
# 20615  /iJCJ1ThBmuYtJyi3rgQWl56qVXt.jpg     2989
# 16026  /42ByqU555QR05IQnjRNDXtrjQu5.jpg    54770
# 3312   /frlfy7RFqx5J4jrcMo25PqyasL3.jpg   295693
# 1417    /Zgvt4ZQH5MUEm5zZUoeklHo8Ph.jpg  1266125
# 2036   /jzZHe9Pv13u7R1U8NK0MiMESRwW.jpg    11317
# 8140   /iuW78LWxApCvjLuMebcICwF2owQ.jpg   465086
# ...

# %%
file_path = '/content/drive/My Drive/movie.csv'

# Save the DataFrame to the specified file path
df.to_csv(file_path, index=False)

# %%
df1 = pd.read_csv('movie.csv')

# %%
df1.head()
# Out:
#    adult  gender       id known_for_department             name  \
# 0  False       1  1696016               Acting    Chloe Coleman
# 1  False       1  1254975               Acting   Shin Hyun-been
# 2  False       2       85               Acting      Johnny Depp
# 3  False       2       64               Acting      Gary Oldman
# 4  False       2  2786960               Acting  Gabriel Guevara
#
#      original_name  popularity                      profile_path  \
# 0    Chloe Coleman     260.448  /rTbVFZMvUViFCIa5AXlBX3P6vfR.jpg
# 1              신현빈     231.228  /ajYk4UgT4hYCvfo0LA1SFJt9mTU.jpg
# 2      Johnny Depp     195.325  /wcI594cwM4ArPwvRd2IU0Z0yLuh.jpg
# 3      Gary Oldman     193.947  /2v9FVVBUrrkW2m3QOcYkuhq9A6o.jpg
# 4  Gabriel Guevara     193.248  /pviRYKEEmoPUfLYwP1VHJ6LQcRg.jpg
#
#                                            known_for
# 0  [{'backdrop_path': '/eEF40Xk2twM3WjRNZftfo771g...
# 1  [{'backdrop_path': '/lkUYS8K3tqOJsYHCKSWIMbG7p...
# ...

# %%
import ast
def extract_known_for_info(known_for_list):
    result = []
    for item in known_for_list:
        result.append({
            'backdrop_path': item.get('backdrop_path'),
            'id': item.get('id'),
            'title': item.get('title'),
            'original_title': item.get('original_title'),
            'overview': item.get('overview'),
            'poster_path': item.get('poster_path'),
            'media_type': item.get('media_type'),
            'adult': item.get('adult'),
            'original_language': item.get('original_language'),
            'genre_ids': item.get('genre_ids'),
            'popularity': item.get('popularity'),
            'release_date': item.get('release_date'),
            'video': item.get('video'),
            'vote_average': item.get('vote_average'),
            'vote_count': item.get('vote_count')
        })
    return result

# Parse 'Known_for' column and expand it
df1['known_for'] = df1['known_for'].apply(ast.literal_eval)  # Convert string representation of list to actual list
df1 = df1['known_for'].apply(pd.Series).stack().reset_index(level=1, drop=True)
df1 = pd.DataFrame(df1.tolist())

# %%
lis = ['name', 'original_name', 'first_air_date', 'origin_country']
for i in lis:
    if i in df1.columns:
        df1.drop(i, axis= 1, inplace=True)

# %%
df1.isna().sum()
# Out:
# backdrop_path         357
# id                      0
# title                6766
# original_title       6766
# overview                0
# poster_path            20
# media_type              0
# adult                   0
# original_language       0
# genre_ids               0
# popularity              0
# release_date         6766
# video                6766
# vote_average            0
# vote_count              0
# dtype: int64

# %%
df1.dropna(inplace=True)

# %%
df1.isna().sum()
# Out:
# backdrop_path        0
# id                   0
# title                0
# original_title       0
# overview             0
# poster_path          0
# media_type           0
# adult                0
# original_language    0
# genre_ids            0
# popularity           0
# release_date         0
# video                0
# vote_average         0
# vote_count           0
# dtype: int64

# %%
df1.shape
# Out:
# (22840, 15)

# %%
genre_mapping = {
    28: 'Action',
    12: 'Adventure',
    16: 'Animation',
    35: 'Comedy',
    80: 'Crime',
    99: 'Documentary',
    18: 'Drama',
    10751: 'Family',
    14: 'Fantasy',
    36: 'History',
    27: 'Horror',
    10402: 'Music',
    9648: 'Mystery',
    10749: 'Romance',
    878: 'Science Fiction',
    10770: 'TV Movie',
    53: 'Thriller',
    10752: 'War',
    37: 'Western'
}

# Function to map genres and return a string
def map_genres_to_string(number_list):
    genre_names = [genre_mapping.get(num, 'Unknown') for num in number_list]
    return ', '.join(genre_names)

# Apply the function to convert the genre list into a string
df1['genre_names'] = df1['genre_ids'].apply(map_genres_to_string)

# %%
# Count occurrences of 'Unknown' in the 'genre_names' column
unknown_count = df1['genre_names'].apply(lambda x: 'Unknown' in x).sum()

# %%
unknown_count
# Out:
# 0

# %%
df2 = pd.read_csv('discovered_movies.csv', lineterminator='\n')

# %%
df2.head()
# Out:
#    adult                     backdrop_path                genre_ids       id  \
# 0  False  /xg27NrXi7VXCGUr7MG75UqLl6Vg.jpg  [16, 10751, 18, 12, 35]  1022789
# 1  False  /fqv8v6AycXKsivp1T5yKtLbGXce.jpg            [878, 12, 28]   653346
# 2  False  /j29ekbcLpBvxnGk6LjdTc2EI5SA.jpg  [16, 10751, 12, 18, 35]   150540
# 3  False  /iTWrsOVsUqcwYSxrpINNs3hG2nC.jpg       [53, 27, 28, 9648]  1001311
# 4  False  /gRApXuxWmO2forYTuTmcz5RaNUV.jpg         [28, 80, 53, 35]   573435
#
#   original_language                     original_title  \
# 0                en                       Inside Out 2
# 1                en  Kingdom of the Planet of the Apes
# 2                en                         Inside Out
# 3                fr                      Sous la Seine
# 4                en              Bad Boys: Ride or Die
#
#                                             overview  popularity  \
# 0  Teenager Riley's mind headquarters is undergoi...    8445.266
# ...

# %%
genre_mapping = {
    28: 'Action',
    12: 'Adventure',
    16: 'Animation',
    35: 'Comedy',
    80: 'Crime',
    99: 'Documentary',
    18: 'Drama',
    10751: 'Family',
    14: 'Fantasy',
    36: 'History',
    27: 'Horror',
    10402: 'Music',
    9648: 'Mystery',
    10749: 'Romance',
    878: 'Science Fiction',
    10770: 'TV Movie',
    53: 'Thriller',
    10752: 'War',
    37: 'Western'
}

# Function to map genres and return a string
def map_genres_to_string(number_list):
    genre_names = [genre_mapping.get(num, 'Unknown') for num in number_list]
    return ', '.join(genre_names)

# Apply the function to convert the genre list into a string
df2['genre_names'] = df2['genre_ids'].apply(map_genres_to_string)

# %%
# Count occurrences of 'Unknown' in the 'genre_names' column
unknown_count = df2['genre_names'].apply(lambda x: 'Unknown' in x).sum()

# %%
unknown_count
# Out:
# 10000

# %%
cols = ['backdrop_path', 'id', 'title', 'original_title', 'overview',
       'poster_path', 'adult', 'original_language', 'genre_ids', 'popularity',
       'release_date', 'video', 'vote_average', 'vote_count']
df2 = df2[cols]

# %%
df1.columns
# Out:
# Index(['backdrop_path', 'id', 'title', 'original_title', 'overview',
#        'poster_path', 'media_type', 'adult', 'original_language', 'genre_ids',
#        'popularity', 'release_date', 'video', 'vote_average', 'vote_count',
#        'genre_names'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['adult', 'backdrop_path', 'genre_ids', 'id', 'original_language',
#        'original_title', 'overview', 'popularity', 'poster_path',
#        'release_date', 'title', 'video', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
df1.drop('media_type',axis=1, inplace=True)

# %%
df1.columns
# Out:
# Index(['backdrop_path', 'id', 'title', 'original_title', 'overview',
#        'poster_path', 'adult', 'original_language', 'genre_ids', 'popularity',
#        'release_date', 'video', 'vote_average', 'vote_count', 'genre_names'],
#       dtype='object')

# %%
df1.shape
# Out:
# (22840, 14)

# %%
df2.columns
# Out:
# Index(['backdrop_path', 'id', 'title', 'original_title', 'overview',
#        'poster_path', 'adult', 'original_language', 'genre_ids', 'popularity',
#        'release_date', 'video', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
df = pd.concat([df1, df2], axis=0)

# %%
for col in df.columns:
    print(f"Column '{col}':", df[col].apply(type).unique())
# Out:
# Column 'backdrop_path': [<class 'str'> <class 'float'>]
# Column 'id': [<class 'int'>]
# Column 'title': [<class 'str'>]
# Column 'original_title': [<class 'str'>]
# Column 'overview': [<class 'str'> <class 'float'>]
# Column 'poster_path': [<class 'str'> <class 'float'>]
# Column 'adult': [<class 'bool'>]
# Column 'original_language': [<class 'str'>]
# Column 'genre_ids': [<class 'list'> <class 'str'>]
# Column 'popularity': [<class 'float'>]
# Column 'release_date': [<class 'str'> <class 'float'>]
# Column 'video': [<class 'bool'>]
# Column 'vote_average': [<class 'float'>]
# Column 'vote_count': [<class 'int'>]

# %%
genre_mapping = {
    28: 'Action',
    12: 'Adventure',
    16: 'Animation',
    35: 'Comedy',
    80: 'Crime',
    99: 'Documentary',
    18: 'Drama',
    10751: 'Family',
    14: 'Fantasy',
    36: 'History',
    27: 'Horror',
    10402: 'Music',
    9648: 'Mystery',
    10749: 'Romance',
    878: 'Science Fiction',
    10770: 'TV Movie',
    53: 'Thriller',
    10752: 'War',
    37: 'Western'
}

# Function to map genres and return a string
def map_genres_to_string(number_list):
    genre_names = [genre_mapping.get(num, 'Unknown') for num in number_list]
    return ', '.join(genre_names)

# Apply the function to convert the genre list into a string
df['genre_names'] = df['genre_ids'].apply(map_genres_to_string)

# %%
df
# Out:
#                          backdrop_path      id  \
# 0     /eEF40Xk2twM3WjRNZftfo771gjv.jpg  700391
# 1     /4xIBM8RwIvpwMlJSoF6tqFOaB6N.jpg  592834
# 2     /oblUNeHlwV3VsjB5ITMlco5ZSOF.jpg  493529
# 3     /lkUYS8K3tqOJsYHCKSWIMbG7ptj.jpg  571625
# 4     /1yqVaDR7uIA3Xx9GQIhbEbh5pEe.jpg  571648
# ...                                ...     ...
# 9995  /qqthj8EUL4QKlDBoMcPqeWvi6Ya.jpg  756403
# 9996  /rVwsqRYQk3pz4irrqaOQcLTTKlM.jpg   14584
# 9997  /eCtRseKCbltn8C6XW1GhqW0c4VA.jpg   10646
# 9998  /kGinxaX9yrpfKqYAxRpdVFUcEAH.jpg    9830
# 9999  /y319VH0gIFie6KEO5L4nHhxxQUw.jpg    9437
#
#                                         title  \
# 0                                          65
# 1                                      My Spy
# 2     Dungeons & Dragons: Honor Among Thieves
# 3                                  The Closet
# 4                    Beasts Clawing at Straws
# ...                                       ...
# 9995       Riverdance: The Animated Adventure
# ...

# %%
genre_mapping = {
    28: 'Action',
    12: 'Adventure',
    16: 'Animation',
    35: 'Comedy',
    80: 'Crime',
    99: 'Documentary',
    18: 'Drama',
    10751: 'Family',
    14: 'Fantasy',
    36: 'History',
    27: 'Horror',
    10402: 'Music',
    9648: 'Mystery',
    10749: 'Romance',
    878: 'Science Fiction',
    10770: 'TV Movie',
    53: 'Thriller',
    10752: 'War',
    37: 'Western'
}
# Define the function for mapping and joining
def map_genres_to_string(number_list):
    return ', '.join([genre_mapping.get(num, 'Unknown') for num in number_list])

# Apply the function to the DataFrame
df['genre_names'] = df['genre_ids'].apply(map_genres_to_string)

# %% [markdown]
# movie ids was compiled and save [here](https://www.themoviedb.org/talk/5f58b094befb0900355684a6)

# %%
df.drop('genre_ids', inplace=True, axis=1)
cols = ['backdrop_path', 'id', 'title', 'original_title', 'overview',
       'poster_path', 'adult', 'original_language', 'genre_names', 'popularity',
       'release_date', 'video', 'vote_average', 'vote_count']
df = df[cols]

# %%
df.drop_duplicates(inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# backdrop_path        0
# id                   0
# title                0
# original_title       0
# overview             0
# poster_path          0
# adult                0
# original_language    0
# genre_names          0
# popularity           0
# release_date         0
# video                0
# vote_average         0
# vote_count           0
# dtype: int64

# %%
df['release_date'] = pd.to_datetime(df['release_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18274 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   backdrop_path      18274 non-null  object
#  1   id                 18274 non-null  int64
#  2   title              18274 non-null  object
#  3   original_title     18274 non-null  object
#  4   overview           18274 non-null  object
#  5   poster_path        18274 non-null  object
#  6   adult              18274 non-null  bool
#  7   original_language  18274 non-null  object
#  8   genre_names        18274 non-null  object
#  9   popularity         18274 non-null  float64
#  10  release_date       18273 non-null  datetime64[ns]
#  11  video              18274 non-null  object
#  12  vote_average       18274 non-null  float64
#  13  vote_count         18274 non-null  int64
# dtypes: bool(1), datetime64[ns](1), float64(2), int64(2), object(8)
# memory usage: 2.0+ MB

# %%
df
# Out:
#                          backdrop_path      id  \
# 0     /eEF40Xk2twM3WjRNZftfo771gjv.jpg  700391
# 1     /4xIBM8RwIvpwMlJSoF6tqFOaB6N.jpg  592834
# 2     /oblUNeHlwV3VsjB5ITMlco5ZSOF.jpg  493529
# 3     /lkUYS8K3tqOJsYHCKSWIMbG7ptj.jpg  571625
# 4     /1yqVaDR7uIA3Xx9GQIhbEbh5pEe.jpg  571648
# ...                                ...     ...
# 9995  /qqthj8EUL4QKlDBoMcPqeWvi6Ya.jpg  756403
# 9996  /rVwsqRYQk3pz4irrqaOQcLTTKlM.jpg   14584
# 9997  /eCtRseKCbltn8C6XW1GhqW0c4VA.jpg   10646
# 9998  /kGinxaX9yrpfKqYAxRpdVFUcEAH.jpg    9830
# 9999  /y319VH0gIFie6KEO5L4nHhxxQUw.jpg    9437
#
#                                         title  \
# 0                                          65
# 1                                      My Spy
# 2     Dungeons & Dragons: Honor Among Thieves
# 3                                  The Closet
# 4                    Beasts Clawing at Straws
# ...                                       ...
# 9995       Riverdance: The Animated Adventure
# ...

# %%
# Count occurrences of 'Unknown' in the 'genre_names' column
unknown_count = df['genre_names'].apply(lambda x: 'Unknown' in x).sum()

# %%
unknown_count
# Out:
# 8145

# %%
df2.tail()
# Out:
#                          backdrop_path      id  \
# 9995  /qqthj8EUL4QKlDBoMcPqeWvi6Ya.jpg  756403
# 9996  /rVwsqRYQk3pz4irrqaOQcLTTKlM.jpg   14584
# 9997  /eCtRseKCbltn8C6XW1GhqW0c4VA.jpg   10646
# 9998  /kGinxaX9yrpfKqYAxRpdVFUcEAH.jpg    9830
# 9999  /y319VH0gIFie6KEO5L4nHhxxQUw.jpg    9437
#
#                                    title                      original_title  \
# 9995  Riverdance: The Animated Adventure  Riverdance: The Animated Adventure
# 9996                 The Cheap Detective                 The Cheap Detective
# 9997                             Tomcats                             Tomcats
# 9998                               Haven                               Haven
# 9999                      Kiss the Girls                      Kiss the Girls
#
#                                                overview  \
# 9995  A young Irish boy named Keegan and Spanish gir...
# 9996  A spoof of the entire 1940s detective genre. S...
# ...
